# %%
from ultralytics import YOLO
from ultralytics.utils.benchmarks import benchmark
import glob
import time

# %%
# https://docs.ultralytics.com/integrations/openvino/

model = YOLO("yolov8n.pt")
model.export(format="openvino")
ov_model = YOLO("yolov8n_openvino_model/")

image_paths = glob.glob("../datasets/video_data/images/*.jpg")

start_time = time.time()

for image in image_paths:
    results = ov_model(
        image,
        save=True,
        project="../output",
        name="yolov8_openvino",
        exist_ok=True,
        task="detect",
        conf=0.45,
        iou=0.7,
        device="cpu"
    )

end_time = time.time()

total_time = end_time - start_time
average_time = total_time / len(image_paths)

print(f"Processed {len(image_paths)} images.")
print(f"\nTotal inference time: {total_time:.2f} seconds")
print(f"Average inference time per image: {average_time:.2f} seconds")
# Out:
# Ultralytics 8.3.118 🚀 Python-3.12.3 torch-2.7.0 CPU (Apple M2)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
#
# OpenVINO: starting export with openvino 2025.1.0-18503-6fec06580ab-releases/2025/1...
# OpenVINO: export success ✅ 1.9s, saved as 'yolov8n_openvino_model/' (12.3 MB)
#
# Export complete (2.1s)
# Results saved to /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8
# Predict:         yolo predict task=detect model=yolov8n_openvino_model imgsz=640
# Validate:        yolo val task=detect model=yolov8n_openvino_model imgsz=640 data=coco.yaml
# Visualize:       https://netron.app
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Loading yolov8n_openvino_model for OpenVINO inference...
# Using OpenVINO LATENCY mode for batch=1 inference...
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-27.000_interval.jpg: 640x640 4 cars, 1 truck, 42.6ms
# Speed: 3.1ms preprocess, 42.6ms inference, 11.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-19.000_interval.jpg: 640x640 3 cars, 29.7ms
# Speed: 1.8ms preprocess, 29.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-42.000_interval.jpg: 640x640 5 cars, 1 motorcycle, 30.0ms
# Speed: 1.4ms preprocess, 30.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-38.000_interval.jpg: 640x640 7 cars, 1 truck, 80.5ms
# Speed: 1.2ms preprocess, 80.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-06.000_interval.jpg: 640x640 4 cars, 1 truck, 42.8ms
# Speed: 1.1ms preprocess, 42.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-49.000_interval.jpg: 640x640 4 cars, 28.5ms
# Speed: 1.2ms preprocess, 28.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-12.000_interval.jpg: 640x640 2 cars, 28.9ms
# Speed: 1.2ms preprocess, 28.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-33.000_interval.jpg: 640x640 7 cars, 1 truck, 29.7ms
# Speed: 1.4ms preprocess, 29.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-56.000_interval.jpg: 640x640 3 cars, 27.7ms
# Speed: 1.2ms preprocess, 27.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-09.000_interval.jpg: 640x640 4 cars, 1 truck, 32.1ms
# Speed: 1.1ms preprocess, 32.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-37.000_interval.jpg: 640x640 4 cars, 2 trucks, 28.9ms
# Speed: 1.3ms preprocess, 28.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-52.000_interval.jpg: 640x640 2 cars, 1 truck, 28.6ms
# Speed: 1.2ms preprocess, 28.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-16.000_interval.jpg: 640x640 4 cars, 1 truck, 32.6ms
# Speed: 1.3ms preprocess, 32.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-28.000_interval.jpg: 640x640 5 cars, 29.4ms
# Speed: 1.2ms preprocess, 29.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-59.000_interval.jpg: 640x640 7 cars, 1 truck, 28.0ms
# Speed: 1.1ms preprocess, 28.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-02.000_interval.jpg: 640x640 6 cars, 1 bus, 28.2ms
# Speed: 1.3ms preprocess, 28.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-23.000_interval.jpg: 640x640 5 cars, 31.2ms
# Speed: 1.2ms preprocess, 31.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-46.000_interval.jpg: 640x640 4 cars, 31.9ms
# Speed: 1.0ms preprocess, 31.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-39.000_interval.jpg: 640x640 7 cars, 1 truck, 28.0ms
# Speed: 1.4ms preprocess, 28.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-07.000_interval.jpg: 640x640 5 cars, 1 bus, 27.6ms
# Speed: 1.2ms preprocess, 27.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-43.000_interval.jpg: 640x640 1 person, 3 cars, 1 motorcycle, 2 trucks, 28.7ms
# Speed: 1.1ms preprocess, 28.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-26.000_interval.jpg: 640x640 4 cars, 28.8ms
# Speed: 1.2ms preprocess, 28.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-18.000_interval.jpg: 640x640 3 cars, 28.3ms
# Speed: 1.1ms preprocess, 28.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-57.000_interval.jpg: 640x640 3 cars, 28.2ms
# Speed: 1.3ms preprocess, 28.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-32.000_interval.jpg: 640x640 6 cars, 27.9ms
# Speed: 1.1ms preprocess, 27.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-13.000_interval.jpg: 640x640 3 cars, 27.6ms
# Speed: 1.2ms preprocess, 27.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-48.000_interval.jpg: 640x640 4 cars, 29.5ms
# Speed: 1.2ms preprocess, 29.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-17.000_interval.jpg: 640x640 4 cars, 27.6ms
# Speed: 1.3ms preprocess, 27.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-29.000_interval.jpg: 640x640 6 cars, 27.3ms
# Speed: 1.2ms preprocess, 27.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-53.000_interval.jpg: 640x640 4 cars, 1 truck, 27.6ms
# Speed: 1.2ms preprocess, 27.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-08.000_interval.jpg: 640x640 5 cars, 1 truck, 27.5ms
# Speed: 1.2ms preprocess, 27.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-36.000_interval.jpg: 640x640 4 cars, 2 trucks, 27.6ms
# Speed: 1.1ms preprocess, 27.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-47.000_interval.jpg: 640x640 5 cars, 27.9ms
# Speed: 1.2ms preprocess, 27.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-22.000_interval.jpg: 640x640 4 cars, 28.3ms
# Speed: 1.1ms preprocess, 28.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-03.000_interval.jpg: 640x640 5 cars, 28.2ms
# Speed: 1.1ms preprocess, 28.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-58.000_interval.jpg: 640x640 5 cars, 1 bus, 29.4ms
# Speed: 1.2ms preprocess, 29.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-54.000_interval.jpg: 640x640 4 cars, 27.2ms
# Speed: 1.0ms preprocess, 27.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-31.000_interval.jpg: 640x640 6 cars, 1 truck, 28.4ms
# Speed: 1.2ms preprocess, 28.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-10.000_interval.jpg: 640x640 3 cars, 28.2ms
# Speed: 1.1ms preprocess, 28.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-04.000_interval.jpg: 640x640 1 person, 4 cars, 27.4ms
# Speed: 1.4ms preprocess, 27.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-40.000_interval.jpg: 640x640 4 cars, 1 motorcycle, 1 truck, 28.3ms
# Speed: 1.2ms preprocess, 28.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-25.000_interval.jpg: 640x640 4 cars, 28.1ms
# Speed: 1.2ms preprocess, 28.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-01-00.000_interval.jpg: 640x640 5 cars, 26.3ms
# Speed: 1.2ms preprocess, 26.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-44.000_interval.jpg: 640x640 5 cars, 1 truck, 26.7ms
# Speed: 1.2ms preprocess, 26.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-21.000_interval.jpg: 640x640 3 cars, 27.4ms
# Speed: 1.2ms preprocess, 27.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-00.000_interval.jpg: 640x640 6 cars, 2 buss, 27.0ms
# Speed: 1.2ms preprocess, 27.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-14.000_interval.jpg: 640x640 3 cars, 1 truck, 27.1ms
# Speed: 1.1ms preprocess, 27.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-50.000_interval.jpg: 640x640 4 cars, 27.9ms
# Speed: 1.2ms preprocess, 27.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-35.000_interval.jpg: 640x640 5 cars, 1 truck, 27.9ms
# Speed: 1.1ms preprocess, 27.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-11.000_interval.jpg: 640x640 2 cars, 29.0ms
# Speed: 1.3ms preprocess, 29.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-30.000_interval.jpg: 640x640 5 cars, 1 truck, 29.7ms
# Speed: 1.2ms preprocess, 29.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-55.000_interval.jpg: 640x640 3 cars, 27.6ms
# Speed: 1.2ms preprocess, 27.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-24.000_interval.jpg: 640x640 4 cars, 27.3ms
# Speed: 1.3ms preprocess, 27.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-41.000_interval.jpg: 640x640 1 person, 5 cars, 1 motorcycle, 27.5ms
# Speed: 1.3ms preprocess, 27.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-05.000_interval.jpg: 640x640 4 cars, 27.8ms
# Speed: 1.1ms preprocess, 27.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-01.000_interval.jpg: 640x640 8 cars, 28.3ms
# Speed: 1.1ms preprocess, 28.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-20.000_interval.jpg: 640x640 2 cars, 27.2ms
# Speed: 1.5ms preprocess, 27.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-45.000_interval.jpg: 640x640 2 cars, 1 truck, 28.0ms
# Speed: 1.1ms preprocess, 28.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-34.000_interval.jpg: 640x640 7 cars, 2 trucks, 28.1ms
# Speed: 1.2ms preprocess, 28.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-51.000_interval.jpg: 640x640 3 cars, 27.5ms
# Speed: 1.2ms preprocess, 27.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-15.000_interval.jpg: 640x640 2 cars, 1 truck, 28.2ms
# Speed: 1.2ms preprocess, 28.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to ../output/yolov8_openvino
# Processed 61 images.
#
# Total inference time: 2.65 seconds
# Average inference time per image: 0.04 seconds

# %%
benchmark(
    model = "yolov8n.pt",
    data="coco128.yaml",
    imgsz=640,
    device="cpu",
    format="openvino"
)
# Out:
# Setup complete ✅ (8 CPUs, 8.0 GB RAM, 149.1/460.4 GB disk)
#
# Benchmarks complete for yolov8n.pt on coco128.yaml at imgsz=640 (6.96s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)    FPS
# 0  OpenVINO       ✅       12.3               0.4522                   26.99  37.06
#      Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)    FPS
# 0  OpenVINO       ✅       12.3               0.4522                   26.99  37.06
