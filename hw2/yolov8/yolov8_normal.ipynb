# %%
from ultralytics import YOLO
from ultralytics.utils.benchmarks import benchmark
import glob
import time

# %%
# https://docs.ultralytics.com/models/yolov8/#yolov8-usage-examples
model = YOLO("yolov8n.pt")
image_paths = glob.glob("../datasets/video_data/images/*.jpg")

start_time = time.time()

for image in image_paths:
    results = model(
        image,
        save=True,
        project="../output",
        name="yolov8_normal",
        exist_ok=True,
        task="detect",
        conf=0.45,
        iou=0.7,
        device="cpu"
    )

end_time = time.time()

total_time = end_time - start_time
average_time = total_time / len(image_paths)

print(f"Processed {len(image_paths)} images.")
print(f"\nTotal inference time: {total_time:.2f} seconds")
print(f"Average inference time per image: {average_time:.2f} seconds")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:01<00:00, 4.44MB/s]
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-27.000_interval.jpg: 384x640 4 cars, 1 truck, 41.1ms
# Speed: 1.9ms preprocess, 41.1ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-19.000_interval.jpg: 384x640 3 cars, 35.2ms
# Speed: 0.7ms preprocess, 35.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-42.000_interval.jpg: 384x640 5 cars, 1 motorcycle, 36.6ms
# Speed: 0.8ms preprocess, 36.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-38.000_interval.jpg: 384x640 7 cars, 1 truck, 37.5ms
# Speed: 0.8ms preprocess, 37.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-06.000_interval.jpg: 384x640 4 cars, 1 truck, 34.9ms
# Speed: 0.7ms preprocess, 34.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-49.000_interval.jpg: 384x640 4 cars, 37.4ms
# Speed: 0.7ms preprocess, 37.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-12.000_interval.jpg: 384x640 2 cars, 35.6ms
# Speed: 0.7ms preprocess, 35.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-33.000_interval.jpg: 384x640 7 cars, 1 truck, 36.1ms
# Speed: 0.8ms preprocess, 36.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-56.000_interval.jpg: 384x640 3 cars, 38.4ms
# Speed: 0.8ms preprocess, 38.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-09.000_interval.jpg: 384x640 4 cars, 1 truck, 37.3ms
# Speed: 0.8ms preprocess, 37.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-37.000_interval.jpg: 384x640 4 cars, 2 trucks, 36.8ms
# Speed: 0.8ms preprocess, 36.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-52.000_interval.jpg: 384x640 2 cars, 1 truck, 35.7ms
# Speed: 0.8ms preprocess, 35.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-16.000_interval.jpg: 384x640 4 cars, 1 truck, 35.7ms
# Speed: 0.7ms preprocess, 35.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-28.000_interval.jpg: 384x640 5 cars, 35.3ms
# Speed: 0.8ms preprocess, 35.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-59.000_interval.jpg: 384x640 7 cars, 1 truck, 34.8ms
# Speed: 0.7ms preprocess, 34.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-02.000_interval.jpg: 384x640 6 cars, 1 bus, 36.1ms
# Speed: 0.8ms preprocess, 36.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-23.000_interval.jpg: 384x640 5 cars, 35.7ms
# Speed: 0.7ms preprocess, 35.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-46.000_interval.jpg: 384x640 4 cars, 36.0ms
# Speed: 0.8ms preprocess, 36.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-39.000_interval.jpg: 384x640 7 cars, 1 truck, 35.0ms
# Speed: 0.7ms preprocess, 35.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-07.000_interval.jpg: 384x640 5 cars, 35.6ms
# Speed: 0.8ms preprocess, 35.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-43.000_interval.jpg: 384x640 1 person, 3 cars, 1 motorcycle, 3 trucks, 36.6ms
# Speed: 0.7ms preprocess, 36.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-26.000_interval.jpg: 384x640 4 cars, 36.9ms
# Speed: 0.8ms preprocess, 36.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-18.000_interval.jpg: 384x640 3 cars, 36.4ms
# Speed: 0.8ms preprocess, 36.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-57.000_interval.jpg: 384x640 4 cars, 36.5ms
# Speed: 0.7ms preprocess, 36.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-32.000_interval.jpg: 384x640 6 cars, 35.5ms
# Speed: 0.7ms preprocess, 35.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-13.000_interval.jpg: 384x640 3 cars, 35.1ms
# Speed: 0.7ms preprocess, 35.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-48.000_interval.jpg: 384x640 4 cars, 35.2ms
# Speed: 0.7ms preprocess, 35.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-17.000_interval.jpg: 384x640 4 cars, 37.2ms
# Speed: 0.7ms preprocess, 37.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-29.000_interval.jpg: 384x640 6 cars, 35.7ms
# Speed: 0.7ms preprocess, 35.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-53.000_interval.jpg: 384x640 4 cars, 1 truck, 37.1ms
# Speed: 0.7ms preprocess, 37.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-08.000_interval.jpg: 384x640 4 cars, 1 truck, 36.9ms
# Speed: 0.8ms preprocess, 36.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-36.000_interval.jpg: 384x640 4 cars, 2 trucks, 36.2ms
# Speed: 0.7ms preprocess, 36.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-47.000_interval.jpg: 384x640 5 cars, 36.3ms
# Speed: 0.9ms preprocess, 36.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-22.000_interval.jpg: 384x640 4 cars, 43.5ms
# Speed: 0.8ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-03.000_interval.jpg: 384x640 6 cars, 36.0ms
# Speed: 0.8ms preprocess, 36.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-58.000_interval.jpg: 384x640 5 cars, 1 bus, 35.9ms
# Speed: 0.8ms preprocess, 35.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-54.000_interval.jpg: 384x640 4 cars, 35.2ms
# Speed: 0.8ms preprocess, 35.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-31.000_interval.jpg: 384x640 5 cars, 1 truck, 41.9ms
# Speed: 1.1ms preprocess, 41.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-10.000_interval.jpg: 384x640 3 cars, 40.0ms
# Speed: 0.9ms preprocess, 40.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-04.000_interval.jpg: 384x640 1 person, 4 cars, 42.4ms
# Speed: 0.7ms preprocess, 42.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-40.000_interval.jpg: 384x640 4 cars, 1 motorcycle, 1 truck, 41.3ms
# Speed: 0.7ms preprocess, 41.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-25.000_interval.jpg: 384x640 4 cars, 47.6ms
# Speed: 0.9ms preprocess, 47.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-01-00.000_interval.jpg: 384x640 5 cars, 41.8ms
# Speed: 0.7ms preprocess, 41.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-44.000_interval.jpg: 384x640 5 cars, 1 truck, 41.2ms
# Speed: 0.8ms preprocess, 41.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-21.000_interval.jpg: 384x640 3 cars, 41.2ms
# Speed: 0.8ms preprocess, 41.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-00.000_interval.jpg: 384x640 6 cars, 2 buss, 38.5ms
# Speed: 0.8ms preprocess, 38.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-14.000_interval.jpg: 384x640 3 cars, 1 truck, 40.1ms
# Speed: 0.8ms preprocess, 40.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-50.000_interval.jpg: 384x640 4 cars, 39.6ms
# Speed: 0.9ms preprocess, 39.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-35.000_interval.jpg: 384x640 5 cars, 1 truck, 41.2ms
# Speed: 0.7ms preprocess, 41.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-11.000_interval.jpg: 384x640 2 cars, 41.5ms
# Speed: 0.8ms preprocess, 41.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-30.000_interval.jpg: 384x640 5 cars, 1 truck, 38.4ms
# Speed: 0.8ms preprocess, 38.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-55.000_interval.jpg: 384x640 3 cars, 39.8ms
# Speed: 0.8ms preprocess, 39.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-24.000_interval.jpg: 384x640 4 cars, 1 truck, 39.7ms
# Speed: 0.9ms preprocess, 39.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-41.000_interval.jpg: 384x640 1 person, 5 cars, 1 motorcycle, 40.4ms
# Speed: 0.8ms preprocess, 40.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-05.000_interval.jpg: 384x640 4 cars, 39.2ms
# Speed: 0.8ms preprocess, 39.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-01.000_interval.jpg: 384x640 8 cars, 40.1ms
# Speed: 0.7ms preprocess, 40.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-20.000_interval.jpg: 384x640 2 cars, 38.3ms
# Speed: 1.0ms preprocess, 38.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-45.000_interval.jpg: 384x640 2 cars, 1 truck, 37.9ms
# Speed: 0.7ms preprocess, 37.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-34.000_interval.jpg: 384x640 7 cars, 2 trucks, 37.2ms
# Speed: 0.8ms preprocess, 37.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-51.000_interval.jpg: 384x640 3 cars, 36.4ms
# Speed: 0.7ms preprocess, 36.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
#
# image 1/1 /Users/phucle/Desktop/cmpe258/hw/hw2/yolov8/../data/images/frame_0-00-15.000_interval.jpg: 384x640 2 cars, 1 truck, 37.8ms
# Speed: 0.7ms preprocess, 37.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to ../output/yolov8_normal
# Processed 61 images.
#
# Total inference time: 3.32 seconds
# Average inference time per image: 0.05 seconds

# %%
benchmark(
    model = "yolov8n.pt",
    data="coco128.yaml",
    imgsz=640,
    device="cpu",
    format="-"
)
# Out:
# Setup complete ✅ (8 CPUs, 8.0 GB RAM, 147.3/460.4 GB disk)
#
# Benchmarks complete for yolov8n.pt on coco128.yaml at imgsz=640 (7.67s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#     Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)   FPS
# 0  PyTorch       ✅        6.2               0.4492                   53.18  18.8
#     Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)   FPS
# 0  PyTorch       ✅        6.2               0.4492                   53.18  18.8
